# %%
jawab = "y"

while (jawab == "y") :
  print("\nNama = Maulida Afifah")
  print("NIM  = 2010512066")
  print("Kelas = C")
  print("\nMenghitung berat badan di planet lain")
  print("_______________________________________")
  print("Masukan berat badan anda : ")
  userMark = input()
  userMark = int(userMark)
  
  print("Silahkan pilih di planet mana anda ingin mengetahui berat badan anda")
  print("1. Planet Mercury")
  print("2. Planet Venus")
  print("3. Planet Mars")
  print("4. Planet Pluto")
  print("5. Planet Jupiter")
  print("6. Planet Neptune")
  print("7. Planet Saturn")
  print("8. Planet Uranus")
  print("Masukan pilihan planet : ")
  planet = input()
  planet = int(planet)
  if planet == 1:
    print("Berat badan anda di Merkurius = ",userMark * 0.38)
  elif planet == 2:
    print("Berat badan anda di Venus = ",userMark * 0.91)
  elif planet == 3:
    print("Berat badan anda di Mars = ",userMark * 0.38)
  elif planet == 4:
    print("Berat badan anda di Pluto = ",userMark * 0.04)
  elif planet == 5:
    print("Berat badan anda di Jupiter = ",userMark * 2.34)
  elif planet == 6:
    print("Berat badan anda di Neptune = ",userMark * 1.12)
  elif planet == 7:
    print("Berat badan anda di Saturn = ",userMark * 0.93)
  elif planet == 8:
    print("Berat badan anda di Uranus = ",userMark * 0.92)
  else :
    print("Maaf, Pilihan anda salah!!")

  print("\nApakah anda ingin mengulangi? y/t : ")
  jawab = input()
  jawab = str(jawab)

else :
  print("Terimakasih")
# Out:
# Nama = Maulida Afifah
# NIM  = 2010512066
# Kelas = C
#
# Menghitung berat badan di planet lain
# _______________________________________
# Masukan berat badan anda :
# 1
# Silahkan pilih di planet mana anda ingin mengetahui berat badan anda
# 1. Planet Mercury
# 2. Planet Venus
# 3. Planet Mars
# 4. Planet Pluto
# 5. Planet Jupiter
# 6. Planet Neptune
# 7. Planet Saturn
# 8. Planet Uranus
# Masukan pilihan planet :
# 1
# Berat badan anda di Merkurius =  0.38
#
# Apakah anda ingin mengulangi? y/t :
# y
#
# Nama = Maulida Afifah
# NIM  = 2010512066
# Kelas = C
#
# Menghitung berat badan di planet lain
# _______________________________________
# Masukan berat badan anda :
# 46
# Silahkan pilih di planet mana anda ingin mengetahui berat badan anda
# 1. Planet Mercury
# 2. Planet Venus
# 3. Planet Mars
# 4. Planet Pluto
# 5. Planet Jupiter
# 6. Planet Neptune
# 7. Planet Saturn
# 8. Planet Uranus
# Masukan pilihan planet :
# 8
# Berat badan anda di Uranus =  42.32
#
# ...
